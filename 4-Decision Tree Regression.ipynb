# %% [markdown]
# * Decision Tree
# * CART : Classification and Regression Tree
# * Regresyon : Eldeki belli datayla başka test verisini tahmin etmek
# * x1 ve x2 bağımsız feature , y ise x1 ve x2'ye bağımlı
# * information entropy formülüne göre datamızı split edicez
# * ![resim](4.jpg)

# %%
# Sondaki 65 , 600 gibi değerler o bulundukları alanın ortalamasıdır.
# Bu şekilde bir ağaç tasarlıyoruz.
# Amaç : error sıfırlamak. Splitler information entropye göre çizilir.
# Bizim modelimiz yukarıdaki gibi olacaktır.
# 3 boyutlu anlattık ancak 2 boyutlu görselleştirme yapıcaz

# %%
# Datasetimizde stat seviyesi - fiyat ilişisini inceleyeceğiz.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("decision+tree+regression+dataset.csv",sep=";", header=None) # header ilk datayı kaybetmemizi sağladı.
df.head()
# Out:
#    0    1
# 0  1  100
# 1  2   80
# 2  3   70
# 3  4   60
# 4  5   50

# %%
x = df.iloc[:,0].values.reshape(-1,1)

y = df.iloc[:,1].values.reshape(-1,1)

# %%
# decision tree regression
from sklearn.tree import DecisionTreeRegressor
tree_reg = DecisionTreeRegressor()
tree_reg.fit(x,y) # ağaç yapımızı oluşturduk
# Out:
# DecisionTreeRegressor()

# %%
tree_reg.predict([[6]])
# Out:
# array([40.])

# %%
tree_reg.predict([[5.5]])
# Out:
# array([50.])

# %%
y_head = tree_reg.predict(x)
y_head
# Out:
# array([100.,  80.,  70.,  60.,  50.,  40.,  30.,  20.,  10.,   5.])

# %%
plt.scatter(x,y,color = "red")
plt.plot(x,y_head, color ="green")
plt.xlabel("tribün level")
plt.ylabel("ücret")
plt.show()

# %%
# bu şekilde olmaması gerekir . Biz istediğimiz değerleri predict ettik. Büyük bir aralıkta predict edilmeli.

# %%
x_ = np.arange(min(x),max(x),0.01).reshape(-1,1)
y_head = tree_reg.predict(x_)
plt.scatter(x,y,color="red")
plt.plot(x_,y_head,color = "green")
plt.xlabel("tribun level")
plt.ylabel("ucret")
plt.show()
# Out:
# C:\Users\Rasit\AppData\Local\Temp\ipykernel_21620\2237555713.py:1: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   x_ = np.arange(min(x),max(x),0.01).reshape(-1,1)

# %%
# yukarıdaki grafik belirli aralıklarda belli değerlerin aynı olduğunu gösterir.
# Aynı resim 4 deki gibi yani resim de 10 - 50 arasında bir ortalama değer vardır 15'te de 14'de de 13'te de 37'de de aynı değeri veriyordu
